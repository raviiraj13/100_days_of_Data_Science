# %% [markdown]
# <a href="https://colab.research.google.com/github/raviiraj13/100_days_of_Data_Science/blob/main/Day2_pandas1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #Creating Series

# %% [markdown]
# we can create a series in different ways

# %%
labels = ['a','b','c','d','e']
my_list = [5,7,6,1,3]
arr = np.array([5,7,6,1,3])
my_dict = {'First':5,'Second':7,'Third':6,'Fourth':1,'Fifth':3}

# %%
pd.Series(my_list)
# Out:
# 0    5
# 1    7
# 2    6
# 3    1
# 4    3
# dtype: int64

# %%
pd.Series(my_list,index = labels)
# Out:
# a    5
# b    7
# c    6
# d    1
# e    3
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    5
# 1    7
# 2    6
# 3    1
# 4    3
# dtype: int64

# %%
pd.Series(my_dict)
# Out:
# First     5
# Second    7
# Third     6
# Fourth    1
# Fifth     3
# dtype: int64

# %% [markdown]
# #Creating a Dataframe

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
df2
# Out:
#        0   1         2      3
# 0   John  28  New York  65000
# 1   Anna  34     Paris  70000
# 2  Peter  29    Berlin  62000
# 3  Linda  42    London  85000

# %%
col = ['Name','Age','City','Salary']
df2 = pd.DataFrame(data_list,columns=col)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# #Selection and indexing of column

# %%
df2['Name']
# Out:
# 0     John
# 1     Anna
# 2    Peter
# 3    Linda
# Name: Name, dtype: object

# %%
df2[['Name','City']]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %% [markdown]
# #Creating a Column

# %%
df2['Designation'] = ['Engg','Doct','Lawy','Teach']
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000        Engg
# 1   Anna   34     Paris   70000        Doct
# 2  Peter   29    Berlin   62000        Lawy
# 3  Linda   42    London   85000       Teach

# %% [markdown]
# #Deleting row

# %%
df2.drop('Designation',axis=1) # it temporary remove from dataframe we need to use inplace
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000        Engg
# 1   Anna   34     Paris   70000        Doct
# 2  Peter   29    Berlin   62000        Lawy
# 3  Linda   42    London   85000       Teach

# %%
df2.drop('Designation',axis=1,inplace=True)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#mutiple row deleting
df2.drop(['Age','City'],axis=1)
# Out:
#     Name  Salary
# 0   John   65000
# 1   Anna   70000
# 2  Peter   62000
# 3  Linda   85000

# %% [markdown]
# #Selecting a Row

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2.loc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %%
df2.loc[[0,1,2]]
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000

# %%
df.iloc[3]
# Out:
# Name       Linda
# Age           42
# City      London
# Salary     85000
# Name: 3, dtype: object

# %% [markdown]
# #Selection of Subset of Row and Columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df.loc[[1,2]][['City','Salary']]
# Out:
#      City  Salary
# 1   Paris   70000
# 2  Berlin   62000

# %% [markdown]
# #Conditional Selection

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
#only select age>30
df2[(df2['Age']>30 )& (df2['City'] == 'Paris')]
# Out:
#    Name  Age   City  Salary
# 1  Anna   34  Paris   70000

# %% [markdown]
# #Missing Data

# %% [markdown]
# finding Missing data

# %%
data = {
    'A': [1, 2, np.nan, 4, 5],
    'B': [1, 2, 3, 4, 5],
    'C': [1, 2, 3, np.nan, np.nan],
    'D': [1, np.nan, np.nan, np.nan, 5]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.isna()
# Out:
#        A      B      C      D
# 0  False  False  False  False
# 1  False  False  False   True
# 2   True  False  False   True
# 3  False  False   True   True
# 4  False  False   True  False

# %%
df.isna().sum()
# Out:
# A    1
# B    0
# C    2
# D    3
# dtype: int64

# %%
df.isna().any()
# Out:
# A     True
# B    False
# C     True
# D     True
# dtype: bool

# %% [markdown]
# #Removing Missing Data

# %%
cf=df.dropna() #basis of rows

# %%
cf
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.dropna(thresh=3) #atleast 3 nonnull value
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 4  5.0  5  NaN  5.0

# %% [markdown]
# #Filling Missing Value

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(5000)
# Out:
#         A  B       C       D
# 0     1.0  1     1.0     1.0
# 1     2.0  2     2.0  5000.0
# 2  5000.0  3     3.0  5000.0
# 3     4.0  4  5000.0  5000.0
# 4     5.0  5  5000.0     5.0

# %%
values={
    'A':0,
    'B':1,
    'C':2,
    'D':3
}
df.fillna(value=values)
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  0.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0

# %%
df
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  NaN
# 2  NaN  3  3.0  NaN
# 3  4.0  4  NaN  NaN
# 4  5.0  5  NaN  5.0

# %%
df.fillna(df.mean())
# Out:
#      A  B    C    D
# 0  1.0  1  1.0  1.0
# 1  2.0  2  2.0  3.0
# 2  3.0  3  3.0  3.0
# 3  4.0  4  2.0  3.0
# 4  5.0  5  2.0  5.0
